# %%
# !pip install pyforest
import pyforest

# %%
df = pd.read_excel('/content/Incinerator.xlsx')
df.head()
# Out:
#    year  age  agesq  nbh   cbd  ...  lintstsq  nearinc  y81nrinc   rprice  lrprice
# 0  1978   48   2304    4  3000  ...  47.71770        1         0  60000.0  11.00210
# 1  1978   83   6889    4  4000  ...  47.71770        1         0  40000.0  10.59663
# 2  1978   58   3364    4  4000  ...  47.71770        1         0  34000.0  10.43412
# 3  1978   11    121    4  4000  ...  47.71770        1         0  63900.0  11.06507
# 4  1978   48   2304    4  4000  ...  57.77368        1         0  44000.0  10.69195
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (321, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      321 non-null    int64
#  1   age       321 non-null    int64
#  2   agesq     321 non-null    int64
#  3   nbh       321 non-null    int64
#  4   cbd       321 non-null    int64
#  5   intst     321 non-null    int64
#  6   lintst    321 non-null    float64
#  7   price     321 non-null    int64
#  8   rooms     321 non-null    int64
#  9   area      321 non-null    int64
#  10  land      321 non-null    int64
#  11  baths     321 non-null    int64
#  12  dist      321 non-null    int64
#  13  ldist     321 non-null    float64
#  14  wind      321 non-null    int64
#  15  lprice    321 non-null    float64
#  16  y81       321 non-null    int64
#  17  larea     321 non-null    float64
#  18  lland     321 non-null    float64
#  19  y81ldist  321 non-null    float64
# ...

# %%
df.describe()
# Out:
#               year         age  ...         rprice    lrprice
# count   321.000000  321.000000  ...     321.000000  321.000000
# mean   1979.327103   18.009346  ...   83721.355483   11.261377
# std       1.492329   32.565845  ...   33118.785771    0.387900
# min    1978.000000    0.000000  ...   26000.000000   10.165850
# 25%    1978.000000    0.000000  ...   59000.000000   10.985290
# 50%    1978.000000    4.000000  ...   82000.000000   11.314470
# 75%    1981.000000   22.000000  ...  100230.400000   11.515230
# max    1981.000000  189.000000  ...  300000.000000   12.611540
#
# [8 rows x 25 columns]

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(), linewidths=1, annot = True, cmap = 'magma')

# %%
x = df.area
y = df.price
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(x,y,color='b',marker= 'o')
plt.title('Plot')
plt.show()

# %%
sns.jointplot(data = df, x= 'area'	, y = 'price', kind = 'reg')

# %%
from sklearn.model_selection import train_test_split
X = df[['area']]
y = df[['price']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 5)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lm.predict(X_test)

# %%
lm.coef_
# Out:
# array([[36.52969007]])

# %%
lm.intercept_
# Out:
# array([18406.81289152])

# %%
plt.scatter(X_test,y_test, color = 'm')
plt.plot(X_test,lm.predict(X_test))
plt.show()

# %%
sklearn.metrics.r2_score(y_test, y_pred)
# Out:
# 0.4584022086064594

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 36617.84562472824

# %%
X = df[['area', 'age', 'cbd', 'intst', 'nbh', 'rooms', 'land', 'baths', 'dist']]
y = df[['price']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 5)
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([[ 2.49531447e+01, -2.98222908e+02,  6.68412395e-01,
#         -9.67666652e-01, -3.16292587e+03,  1.77772185e+03,
#         -2.36421480e-02,  1.02490336e+04,  4.21325730e-01]])

# %%
model.intercept_
# Out:
# array([17480.72445828])

# %%
sklearn.metrics.r2_score(y_test, y_pred)
# Out:
# 0.5185014986366012

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 34526.44128400082
